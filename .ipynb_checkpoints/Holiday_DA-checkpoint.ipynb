# %%
import pandas as pd
from glob import glob
import os
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
if os.name == 'posix':
    plt.rc("font", family = "AppleGothic")
else:
    plt.rc("font", family = "Malgun Gothic")

# %%
now = os.getcwd()
country_codes = ['GR', 'NL', 'NO', 'NZ', 'TW', 'KR', 'DK', 'DE', 'LV', 'LU', 'LT', 'MO', 'MT', 'US', 'BE',
                 'SM', 'SE', 'CH', 'ES', 'SK', 'SI', 'SG', 'IS', 'IE', 'AD', 'EE', 'GB', 'AT', 'IL', 'IT',
                'JP', 'CZ', 'CA', 'HR', 'CY', 'PT', 'PR', 'FR', 'FI', 'AU', 'HK' ]

df = pd.read_csv(glob('Holiday_datas/*_GR.csv')[0])

# %%
for code in country_codes[1:]:
    loc = glob(now + f'/Holiday_data/*_{code}.csv')[0]
    df_plus = pd.read_csv(loc)
    df = pd.concat([df, df_plus])

# %%
National_holiday = df[(df['Country Code'] == 'GR') & (df['Type'].str.contains('National holiday'))]
                                                    
for code in country_codes[1:]:
    loc = df[(df['Country Code'] == code) & (df['Type'].str.contains('National holiday'))]                                            
    National_holiday = pd.concat([National_holiday, loc])

# 전체 국가들의 휴일 중에서 선진국이면서 공휴일인 날 들을 모두 모은다.

# %%
National_holiday
# Out:
#           Date                                               Name  \
# 0   2023-01-01                                     New Year's Day
# 1   2023-01-06                                           Epiphany
# 4   2023-02-27                                       Clean Monday
# 6   2023-03-25                             Greek Independence Day
# 7   2023-03-25                    Annunciation of the Virgin Mary
# ..         ...                                                ...
# 25  2023-10-01     National Day of the People's Republic of China
# 26  2023-10-02  National Day of the People's Republic of China...
# 27  2023-10-23                               Chung Yeung Festival
# 30  2023-12-25                                      Christmas Day
# 31  2023-12-26                  First Weekday After Christmas Day
#
#                     Type Country Name Country Code
# 0   ['National holiday']       Greece           GR
# 1   ['National holiday']       Greece           GR
# 4   ['National holiday']       Greece           GR
# 6   ['National holiday']       Greece           GR
# 7   ['National holiday']       Greece           GR
# ..                   ...          ...          ...
# 25  ['National holiday']    Hong Kong           HK
# 26  ['National holiday']    Hong Kong           HK
# 27  ['National holiday']    Hong Kong           HK
# 30  ['National holiday']    Hong Kong           HK
# 31  ['National holiday']    Hong Kong           HK
#
# [1087 rows x 5 columns]

# %% [markdown]
# 선진국 리스트 : 그리스 네덜란드 노르웨이 뉴질랜드 대만 대한민국 덴마크 독일 라트비아 룩셈부르크 리투아니아 마카오 몰타 미국 벨기에
#             산마리노 스웨덴 스위스 스페인 슬로바키아 슬로베니아 싱가포르 아이슬란드 아일랜드 안도라 에스토니아 영국 오스트리아 이스라엘
#             이탈리아 일본 체코 캐나다 크로아티아 키프로스 포르투갈 푸에르토리코 프랑스 핀란드 호주 홍콩

# %%
plt.figure(figsize = (15, 4))
n = National_holiday['Country Code'].value_counts()
n.plot.bar(rot = 0, xlabel = '나라명', ylabel = '공휴일 수')
# 전체 선진국들의 공휴일의 수 차트
# Out:
# <Axes: xlabel='나라명', ylabel='공휴일 수'>

# %%
df_oecd = pd.read_csv(glob('OECD_worktime_data/DP_*')[0])
# oecd의 년 근로시간

# %%
df_work_time = df_oecd[df_oecd['TIME'] == 2022]

# %%
df_work_time = df_work_time.sort_values(by = 'Value', ascending = False)
df_work_time.plot.bar(color = 'skyblue', rot = 40, x = 'LOCATION', y = 'Value',
                      ylabel = '연 평균 근로시간', xlabel = '나라명', figsize = (15,4))
# Out:
# <Axes: xlabel='나라명', ylabel='연 평균 근로시간'>

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 6))  # 1 row, 2 columns

df_top5 = df_work_time.sort_values(by = 'Value', ascending = False).head(5)
df_bottom5 = df_work_time.sort_values(by = 'Value', ascending = False).tail(5)

df_top5.plot.bar(rot = 0, x = "LOCATION", y = 'Value', ax = axes[0], color = ['pink'])
axes[0].set_title('Top 5 Work Times')

df_bottom5.plot.bar(rot = 0, x = "LOCATION", y = 'Value', ax = axes[1], color = 'skyblue')
axes[1].set_title('Bottom 5 Work Times')
axes[1].set_ylim(0,2300)
plt.tight_layout()

plt.show()

# %%
happiness_top5 = {'MEX' : 46, 'CRI' : 23, 'CHL' : 44, 'KOR' : 59, 'ISR' : 3}
happiness_bottom5 = {'SWE' : 7, 'NLD' : 5, 'NCR' : 8, 'DNK' : 2, 'DEU' : 14}
# SDSN : Sustainable Development Solutions Network 행복지수 2021

# %%
df_SDSN = pd.read_excel(glob('SDSN 행복지수/*')[0])

# %%
df_SDSN['Country name']
holiday_count = National_holiday.groupby(['Country Name'])['Country Name'].count()

# %%
print(df_SDSN.columns)
df_SDSN.sample(5)
# Out:
# Index(['Country name', 'Ladder score', 'Standard error of ladder score',
#        'upperwhisker', 'lowerwhisker', 'Logged GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')
#                Country name  Ladder score  Standard error of ladder score  \
# 88                     Laos        5.1107                        0.080944
# 104                 Namibia        4.6308                        0.068877
# 74                     Peru        5.5259                        0.057994
# 70   Bosnia and Herzegovina        5.6325                        0.072670
# 32                    Italy        6.4045                        0.054325
#
#      upperwhisker  lowerwhisker  Logged GDP per capita  Social support  \
# 88       5.269351      4.952050               8.962409        0.678947
# 104      4.765799      4.495800               9.120739        0.786925
# 74       5.639568      5.412232               9.401519        0.797965
# 70       5.774934      5.490066               9.615764        0.880300
# 32       6.510976      6.298024              10.634051        0.881570
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 88                 60.945587                      0.918855    0.090989
# 104                56.851330                      0.669482   -0.125577
# 74                 69.849838                      0.794370   -0.118852
# 70                 67.275032                      0.746143    0.206407
# 32                 72.050003                      0.710514   -0.073543
#
#      Perceptions of corruption  Ladder score in Dystopia  \
# 88                    0.702522                  1.777825
# 104                   0.830382                  1.777825
# 74                    0.891712                  1.777825
# 70                    0.917538                  1.777825
# 32                    0.841754                  1.777825
#
#      Explained by: Log GDP per capita  Explained by: Social support  \
# 88                           1.232199                      0.852801
# 104                          1.288984                      1.125555
# 74                           1.389685                      1.153443
# 70                           1.466523                      1.361425
# 32                           1.831729                      1.364630
#
#      Explained by: Healthy life expectancy  \
# 88                                0.256538
# 104                               0.144983
# 74                                0.499149
# 70                                0.428994
# 32                                0.559096
#
#      Explained by: Freedom to make life choices  Explained by: Generosity  \
# 88                                     0.714884                  0.185251
# 104                                    0.383037                  0.069053
# 74                                     0.549228                  0.072661
# 70                                     0.485052                  0.247178
# 32                                     0.437638                  0.096972
#
#      Explained by: Perceptions of corruption  Dystopia + residual
# 88                                  0.162283             1.706761
# 104                                 0.070701             1.548512
# 74                                  0.026772             1.835006
# 70                                  0.008274             1.635025
# 32                                  0.062556             2.051905

# %%
df_oecd[df_oecd['TIME'] == 2022]
# Out:
#      LOCATION INDICATOR SUBJECT MEASURE FREQUENCY  TIME        Value  \
# 37        AUS     HRWKD     TOT  HR_WKD         A  2022  1707.325609
# 65        AUT     HRWKD     TOT  HR_WKD         A  2022  1443.720369
# 179       CAN     HRWKD     TOT  HR_WKD         A  2022  1686.000000
# 209       CZE     HRWKD     TOT  HR_WKD         A  2022  1754.050330
# 262       DNK     HRWKD     TOT  HR_WKD         A  2022  1371.606096
# 325       FIN     HRWKD     TOT  HR_WKD         A  2022  1498.068704
# 398       FRA     HRWKD     TOT  HR_WKD         A  2022  1511.400222
# 451       DEU     HRWKD     TOT  HR_WKD         A  2022  1340.861971
# 491       GRC     HRWKD     TOT  HR_WKD         A  2022  1886.293958
# 534       HUN     HRWKD     TOT  HR_WKD         A  2022  1699.600000
# 587       ISL     HRWKD     TOT  HR_WKD         A  2022  1449.219419
# 640       IRL     HRWKD     TOT  HR_WKD         A  2022  1657.468503
# 693       ITA     HRWKD     TOT  HR_WKD         A  2022  1694.452444
# 746       JPN     HRWKD     TOT  HR_WKD         A  2022  1606.995367
# 761       KOR     HRWKD     TOT  HR_WKD         A  2022  1901.000000
# 814       LUX     HRWKD     TOT  HR_WKD         A  2022  1473.257973
# 846       MEX     HRWKD     TOT  HR_WKD         A  2022  2226.300445
# 899       NLD     HRWKD     TOT  HR_WKD         A  2022  1427.015671
# 952       NZL     HRWKD     TOT  HR_WKD         A  2022  1748.000000
# 1013      NOR     HRWKD     TOT  HR_WKD         A  2022  1424.582908
# 1043      POL     HRWKD     TOT  HR_WKD         A  2022  1814.794857
# 1096      PRT     HRWKD     TOT  HR_WKD         A  2022  1635.095304
# 1124      SVK     HRWKD     TOT  HR_WKD         A  2022  1622.066850
# 1177      ESP     HRWKD     TOT  HR_WKD         A  2022  1643.547475
# 1250      SWE     HRWKD     TOT  HR_WKD         A  2022  1440.459124
# 1282      CHE     HRWKD     TOT  HR_WKD         A  2022  1528.660742
# 1387      GBR     HRWKD     TOT  HR_WKD         A  2022  1531.714776
# 1460      USA     HRWKD     TOT  HR_WKD         A  2022  1810.944000
# 1497      CHL     HRWKD     TOT  HR_WKD         A  2022  1962.800000
# 1520      EST     HRWKD     TOT  HR_WKD         A  2022  1770.411485
# 1562      ISR     HRWKD     TOT  HR_WKD         A  2022  1891.900000
# 1619      SVN     HRWKD     TOT  HR_WKD         A  2022  1619.012873
# 1672     OECD     HRWKD     TOT  HR_WKD         A  2022  1751.582467
# 1700      LVA     HRWKD     TOT  HR_WKD         A  2022  1553.235637
# 1728      LTU     HRWKD     TOT  HR_WKD         A  2022  1624.155140
# 1764      CRI     HRWKD     TOT  HR_WKD         A  2022  2149.000000
# 1792      BGR     HRWKD     TOT  HR_WKD         A  2022  1618.733833
# 1872      HRV     HRWKD     TOT  HR_WKD         A  2022  1810.495869
# 1900      CYP     HRWKD     TOT  HR_WKD         A  2022  1837.097004
# 1928      MLT     HRWKD     TOT  HR_WKD         A  2022  1881.929746
# 1956      ROU     HRWKD     TOT  HR_WKD         A  2022  1808.232842
# 1984     EU27     HRWKD     TOT  HR_WKD         A  2022  1570.796361
#
#       Flag Codes
# 37           NaN
# 65           NaN
# 179          NaN
# 209          NaN
# 262          NaN
# 325          NaN
# 398          NaN
# 451          NaN
# 491          NaN
# 534          NaN
# 587          NaN
# 640          NaN
# 693          NaN
# 746          NaN
# 761          NaN
# 814          NaN
# 846          NaN
# 899          NaN
# 952          NaN
# 1013         NaN
# 1043         NaN
# 1096         NaN
# 1124         NaN
# 1177         NaN
# 1250         NaN
# 1282         NaN
# 1387         NaN
# 1460         NaN
# 1497         NaN
# 1520         NaN
# 1562         NaN
# 1619         NaN
# 1672         NaN
# 1700         NaN
# 1728         NaN
# 1764         NaN
# 1792         NaN
# 1872         NaN
# 1900         NaN
# 1928         NaN
# 1956         NaN
# 1984         NaN

# %%
len(df_work_time)
# Out:
# 42

# %%
country_mapping = {'Finland': 'FIN','Denmark': 'DNK','Iceland': 'ISL','Israel': 'ISR',
                   'Netherlands': 'NLD','Sweden': 'SWE','Norway': 'NOR','Switzerland': 'CHE',
                   'Luxembourg': 'LUX','New Zealand': 'NZL','Austria': 'AUT','Australia': 'AUS',
                   'Canada': 'CAN','Ireland': 'IRL','United States': 'USA','Germany': 'DEU',
                   'Belgium': 'BEL','Czechia': 'CZE','United Kingdom': 'GBR','Lithuania': 'LTU',
                   'France': 'FRA','Slovenia': 'SVN','Singapore': 'SGP','Slovakia': 'SVK',
                   'Estonia': 'EST','Spain': 'ESP','Italy': 'ITA','Malta': 'MLT','Latvia': 'LVA',
                   'Cyprus': 'CYP','Japan': 'JPN','Croatia': 'HRV','Portugal': 'PRT',
                   'South Korea': 'KOR',  'Greece': 'GRC'
                    }

# df_seoul[["경도", "위도", "시군구명"]].plot.scatter(x = "경도", y = "위도", figsize = (8,7),grid = True)
name = []
rank = []
work = []
NH_count = []
C_code = []
for i in range(len(df_SDSN)):
    try:
        code = country_mapping[df_SDSN['Country name'][i]]
        work.append(round(df_work_time[df_work_time['LOCATION'] == code]['Value'].values[0],2)) # 연 근로시간
        NH_count.append(holiday_count[df_SDSN['Country name'][i]]) # 휴일 수
        name.append(df_SDSN['Country name'][i])                    # 나라명
        rank.append(i+1)                                           # 행복지수 순위
        C_code.append(country_mapping[df_SDSN['Country name'][i]]) # 국가 코드

    except Exception as e:
        continue

# SDSN의 행복지수와 OECD의 근로시간, 나라별 휴일 수 데이터를 선진국들만 포함하여 새로 작성.

# %%
data = {"국가 이름" : name, "행복지수 순위" : rank, "휴일 수" : NH_count, "연 근로시간" : work, "국가 코드" : C_code}
df_all = pd.DataFrame(data)
df_all.describe()
# Out:
#          행복지수 순위       휴일 수       연 근로시간
# count  33.000000  33.000000    33.000000
# mean   22.757576  24.212121  1629.759697
# std    17.462514   7.043426   164.158498
# min     1.000000   2.000000  1340.860000
# 25%     9.000000  22.000000  1498.070000
# 50%    18.000000  24.000000  1624.160000
# 75%    33.000000  28.000000  1754.050000
# max    58.000000  38.000000  1901.000000

# %%
df_all.sort_values(by = '행복지수 순위',)
# Out:
#              국가 이름  행복지수 순위  휴일 수   연 근로시간 국가 코드
# 0          Finland        1    26  1498.07   FIN
# 1          Denmark        2    22  1371.61   DNK
# 2          Iceland        3    32  1449.22   ISL
# 3           Israel        4    18  1891.90   ISR
# 4      Netherlands        5    22  1427.02   NLD
# 5           Sweden        6    26  1440.46   SWE
# 6           Norway        7    24  1424.58   NOR
# 7      Switzerland        8     2  1528.66   CHE
# 8       Luxembourg        9    22  1473.26   LUX
# 9      New Zealand       10    24  1748.00   NZL
# 10         Austria       11    26  1443.72   AUT
# 11       Australia       12    14  1707.33   AUS
# 12          Canada       13    24  1686.00   CAN
# 13         Ireland       14    20  1657.47   IRL
# 14   United States       15    26  1810.94   USA
# 15         Germany       16    18  1340.86   DEU
# 16         Czechia       18    28  1754.05   CZE
# 17  United Kingdom       19    16  1531.71   GBR
# 18       Lithuania       20    32  1624.16   LTU
# 19          France       21    22  1511.40   FRA
# 20        Slovenia       22    30  1619.01   SVN
# 21        Slovakia       29    30  1622.07   SVK
# 22         Estonia       31    24  1770.41   EST
# 23           Spain       32    18  1643.55   ESP
# 24           Italy       33    24  1694.45   ITA
# 25           Malta       37    28  1881.93   MLT
# 26          Latvia       41    38  1553.24   LVA
# 27          Cyprus       46    28  1837.10   CYP
# 28           Japan       47    34  1607.00   JPN
# 29         Croatia       48    28  1810.50   HRV
# 30        Portugal       56    26  1635.10   PRT
# 31     South Korea       57    34  1901.00   KOR
# 32          Greece       58    13  1886.29   GRC

# %%
# df_all[['행복지수 순위','연 근로시간','국가 이름']].plot.scatter(x = '행복지수 순위', y = '연 근로시간', color = 'green')
plt.title('행복지수 순위와 연 근로시간의 scatterplot')
sns.regplot(x = '행복지수 순위', y = '연 근로시간', data = df_all)
# Out:
# <Axes: title={'center': '행복지수 순위와 연 근로시간의 scatterplot'}, xlabel='행복지수 순위', ylabel='연 근로시간'>

# %%
colors = []
b_count = [0,1,2]
r_count = [30,31,32]
for i in range(len(df_all)):
    if i in b_count:
        colors.append('green')
    elif i in r_count:
        colors.append('red')
    else:
        colors.append('skyblue')
        
plt.rcParams["figure.figsize"] = (15,4)
df_all[['국가 코드', '행복지수 순위','연 근로시간']].sort_values(by = '행복지수 순위').plot.bar(x = '국가 코드',  y = '연 근로시간',
                                                                           color = colors, rot = 0)

# 왼쪽부터 행복지수 순위가 높은 순으로 정렬한 국가별 근로시간 그래프
# Out:
# <Axes: xlabel='국가 코드'>

# %%
df_corr_p = df_all[['행복지수 순위','연 근로시간','휴일 수']].corr(method = 'pearson') # 두 변수 사이의 '선형 관계'의 강도와 방향
print(df_corr_p)
sns.heatmap(df_corr_p)
# Out:
#           행복지수 순위    연 근로시간      휴일 수
# 행복지수 순위  1.000000  0.562134  0.302525
# 연 근로시간   0.562134  1.000000  0.083256
# 휴일 수     0.302525  0.083256  1.000000
# <Axes: >

# %%
df_corr_k = df_all[['행복지수 순위','연 근로시간', '휴일 수']].corr(method='kendall') # 두 변수가 정규 분포를 벗어나는 경우/순위 척도
print(df_corr_k,'\n')
sns.heatmap(df_corr_k)
# Out:
#           행복지수 순위    연 근로시간      휴일 수
# 행복지수 순위  1.000000  0.401515  0.231989
# 연 근로시간   0.401515  1.000000  0.078640
# 휴일 수     0.231989  0.078640  1.000000
# <Axes: >

# %%
df_corr_s = df_all[['행복지수 순위','연 근로시간', '휴일 수']].corr(method='spearman') # 두 변수의 순위 관계에 대해서 사용
print(df_corr_k,'\n')
sns.heatmap(df_corr_s)
# Out:
#           행복지수 순위    연 근로시간      휴일 수
# 행복지수 순위  1.000000  0.401515  0.231989
# 연 근로시간   0.401515  1.000000  0.078640
# 휴일 수     0.231989  0.078640  1.000000
# <Axes: >

# %% [markdown]
# """ 2) method별 상관계수 구하기 """
# df_corr_p = df_all.corr(method='pearson') # 두 변수 사이의 '선형 관계'의 강도와 방향
#
# df_corr_k = df_all.corr(method='kendall') # 두 변수가 정규 분포를 벗어나는 경우/순위 척도
#
# df_corr_s = df_all.corr(method='spearman') # 두 변수의 순위 관계에 대해서 사용
#
# 1에 가까울수록 같이 올라가고, -1에 가까울수록 한쪽이 올라갈 때 다른 한 쪽이 떨어진다.
#
# A와 B의 상관관계가 높다는 이야기는 함께 움직이는 경향이 있다는 것이지,
# "A를 증가하게 만들면 B가 증가할 것이다." 라는 생각은 틀릴 수 있다.

# %%
from scipy import stats
 
# print(stats.ttest_ind(df_all['행복지수 순위'], df_all['연 근로시간'] ),'\n') 
# t-검정은 알 수 없는 두 그룹 모집단 평균이 같은지 여부를 검정하는 데 사용되는 방법이다.
print('--행복지수 순위와 연 근로시간 간의 스피어맨 상관계수--')
print(stats.spearmanr(df_all['행복지수 순위'], df_all['연 근로시간'] ), '\n')
print('--행복지수 순위와 휴일 간의 스피어맨 상관계수--')
print(stats.spearmanr(df_all['행복지수 순위'], df_all['휴일 수'] ), '\n')
print('--행복지수 순위와 연 근로시간 간의 켄달 타우 상관계수--')
print(stats.kendalltau(df_all['행복지수 순위'], df_all['연 근로시간'] ), '\n')
print('--행복지수 순위와 휴일 수 간의 켄달 타우 상관계수--')
print(stats.kendalltau(df_all['행복지수 순위'], df_all['휴일 수'] ), '\n')
# Out:
# --행복지수 순위와 연 근로시간 간의 스피어맨 상관계수--
# SignificanceResult(statistic=0.554144385026738, pvalue=0.0008199316576865252)
#
# --행복지수 순위와 휴일 간의 스피어맨 상관계수--
# SignificanceResult(statistic=0.32518791111205086, pvalue=0.06480780405432247)
#
# --행복지수 순위와 연 근로시간 간의 켄달 타우 상관계수--
# SignificanceResult(statistic=0.40151515151515155, pvalue=0.0008217398680352673)
#
# --행복지수 순위와 휴일 수 간의 켄달 타우 상관계수--
# SignificanceResult(statistic=0.23198879336591172, pvalue=0.06561348246573231)

# %% [markdown]
# output의 첫 숫자는 상관계수 숫자를 의미한다.
# (0.7 이상 정도면 매우 큰 상관관계를 의미함.)
#
# 두번째 숫자는 두 집단 간의 상관관계가 얼마나 유의미한지를 나타내는 p-value 값으로
# 보통 0.05 혹은 0.01 이하 정도면 유의미한 상관이 있다고 간주한다.
#
# pearson :  상관계수는 -1~1의 값을 가지며 -1이나 1에 가까울수록 연관성이 높다. 0에 가까울수록 연관성은 없다.
#
# 아래의 두 상관계수는 비모수적 상관계수이다(모집단의 특정 분포를 가정하지 않고 접근하는 방법. 비모수적 방법은 정규성 검정에서 정규분포를 따르지 않거나 표본의 개수가 10개 미만일 때 사용)
#
# kendall : 켄달 타우 상관계수는 두 변수들 간의 순위를 비교하여 연관성을 계산한다. 켄달 타우는 concordant pair의 수를 이용하여 p를 구한다. (p = (C - not(C)) / (C + not(C)) )
# concordant pair : 예를 들어 킬와 몸무게에 대한 상관계수를 알 때, A가 키가 크고 몸무게도 많이 나가면 concordant pair, A가 키가 크지만 B의 몸무게가 더 나간다고 할 때는 non concordant pari이다.
# 켄달 타우는 샘플 사이즈가 작거나 데이터의 동률이 많을 때 유용하다.
#
# spearman :  순위상관계수는 데이터의 값이 아니라 순위에 의존한다. 스피어만 상관계수는 값에 순의를 매겨 그 순위에 대해 상관계수를 구하는 것이다.
# 연속형 변수가 아닌 순서형인 경우에도 상관계수를 구할 수 있다.
# 스피어만은 데이터 내 편차와 에러에 민감하며 일반적으로 켄달 상관계수보다 높은값을 가진다.
#
# 최소 최대 정규화: 모든 feature들의 스케일이 동일하지만, 이상치(outlier)를 잘 처리하지 못한다.
# Z-점수 정규화 : 이상치(outlier)를 잘 처리하지만, 정확히 동일한 척도로 정규화 된 데이터를 생성하지는 않는다.
#
# P-value란 Probability-value의 줄임말로 확률 값을 뜻하며 어떤 사건이 우연히 발생할 확률을 의미.
# p값이 0.05보다 작다는 것은 어떤 사건이 우연히 일어날 확률이 0.05보다 작다라는 의미이다.
# 보통 P-value가 0.05보다 크면 이 사건은 우연히 발생한 것이다 라고 생각하고 인과관계가 없다고 판단된다.

# %% [markdown]
#
# Min-Max Normalization
# Min-Max Normalization은 데이터의 최솟값을 0, 최댓값을 1로 조정하는 방법. 이 방법은 데이터가 0과 1 사이의 범위 내에 분포하도록 하여, 데이터 분포의 형태가 유지되는 동시에 scale을 조정.
# x_norm = (x - min(x)) / (max(x) - min(x))
#
# Z-score Normalization
# Z-score Normalization은 데이터가 평균을 기준으로 얼마나 떨어져 있는지를 표준편차의 단위로 표시하는 방법. 이 방법은 데이터가 정규분포를 따른다는 가정이 있을 때 가장 효과적이다.
# x_norm = (x - mean(x)) / std(x)
#
# Decimal Scaling Normalization
# Decimal Scaling Normalization은 Min-Max Normalization과 유사한 방법. 하지만 Min-Max Normalization처럼 최소값과 최대값을 사용하지 않고, 가장 큰 자릿수를 10의 거듭제곱으로 나누어 scale을 맞추는 방법. 이 방법은 scale이 어떤 범위에 있는지에 상관없이 적용할 수 있다.
# x_norm = x / 10^j, where j = ceil(log10(max(abs(x))))

# %% [markdown]
# 총평
# 각 나라의 휴일 수와 연 근로시간, 행복지수 순위를 엮어 하나의 데이터 프레임을 형성했음.
# 행복지수는 다양한 요인에 의해 결정되기에 단정지을 수는 없지만, 근로시간이 적을수록 행복지수의 순위가 높아지는 경향을 보였음.
# 행복지수와 휴일 수, 행복지수와 연 근로시간의 관계는 둘 다 스피어맨 검정결과 p-value가 0.05미만으로, 나름의 관계성이 있음을 볼 수 있었다.
#
# 특히, 상관계수를 비교해 봤을 때, 휴일 수 보다는 연 근로시간과의 관계성이 더 두드러졌다.
# 각 변수들의 상관계수를 spearmanr 상관계수와 kendalltau 상관계수로 계산했을 때, spearmanr 상관계수의 값이 조금 더 높았다. p-value는 둘 다 0.05 미만으로 신빙성이 어느정도 보장된다고 볼 수 있었다.
